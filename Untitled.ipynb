# %%
from PIL import Image
import numpy as np

# %%
img= Image.open("..\Data\chair\chair\._image_0001.jpg")
img
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 img= Image.open("..\Data\chair\chair\._image_0001.jpg")
#       2 img
#
# File ~\anaconda3\Lib\site-packages\PIL\Image.py:3493, in open(fp, mode, formats)
#    3491 if is_path(fp):
#    3492     filename = os.fspath(fp)
# -> 3493     fp = builtins.open(filename, "rb")
#    3494     exclusive_fp = True
#    3495 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: '..\\Data\\chair\\chair\\._image_0001.jpg'

# %%
cnn
