# %%
from PIL import Image

# %%
img00 = Image.open("../Data/Face/Aiden/image_0000.jpg")
img00
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 img00 = Image.open("../Data/Face/Aiden/image_0000.jpg")
#       2 img00
#
# File ~\anaconda3\Lib\site-packages\PIL\Image.py:3493, in open(fp, mode, formats)
#    3491 if is_path(fp):
#    3492     filename = os.fspath(fp)
# -> 3493     fp = builtins.open(filename, "rb")
#    3494     exclusive_fp = True
#    3495 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: '../Data/Face/Aiden/image_0000.jpg'
