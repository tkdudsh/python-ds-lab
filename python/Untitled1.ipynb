# %%
# 데이터셋 로드
df1 =pd.read.csv('data/서울특별시 공공자전거 일별 대여건수_25.1-6.csv')
df1.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 # 데이터셋 로드
# ----> 2 df1 =pd.read.csv('data/서울특별시 공공자전거 일별 대여건수_25.1-6.ㅊㄴㅍ')
#       3 df1.head()
#
# NameError: name 'pd' is not defined

# %%
# 데이터셋 로드
df2 =pd.read.csv('data/0BS_ASOS_DD_20250101.csv')
df2.head()

# %%
print(df1
