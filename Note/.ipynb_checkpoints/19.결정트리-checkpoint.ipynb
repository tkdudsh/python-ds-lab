# %% [markdown]
# #### 로지스틱 회귀로 와인 분류하기

# %%
import pandas as pd

# %%
wine = pd.read_csv("../Data/wine.csv")
wine.head()
# Out:
#    alcohol  sugar    pH  class
# 0      9.4    1.9  3.51    0.0
# 1      9.8    2.6  3.20    0.0
# 2      9.8    2.3  3.26    0.0
# 3      9.8    1.9  3.16    0.0
# 4      9.4    1.9  3.51    0.0

# %%
wine.tail()
# Out:
#       alcohol  sugar    pH  class
# 6492     11.2    1.6  3.27    1.0
# 6493      9.6    8.0  3.15    1.0
# 6494      9.4    1.2  2.99    1.0
# 6495     12.8    1.1  3.34    1.0
# 6496     11.8    0.8  3.26    1.0

# %%
# class의 종류 파악
wine['class'].unique()
# Out:
# array([0., 1.])

# %%
wine['class'].value_counts()
# Out:
# class
# 1.0    4898
# 0.0    1599
# Name: count, dtype: int64

# %% [markdown]
# ### 0:Red Wine, 1: White Wine

# %%
wine.info()
data = wine[['alcohol', 'sugar', 'pH']].to_numpy()
target = wine['class'].to_numpy()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6497 entries, 0 to 6496
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   alcohol  6497 non-null   float64
#  1   sugar    6497 non-null   float64
#  2   pH       6497 non-null   float64
#  3   class    6497 non-null   float64
# dtypes: float64(4)
# memory usage: 203.2 KB

# %%
wine.shape
# Out:
# (6497, 4)

# %%
from sklearn.model_selection import train_test_split

# %%
train_input,test_input,train_target,test_target= \
    train_test_split(
        data,
        target,
        test_size=0.2,
        random_state=42
    )

# %%
print("Train:",train_input.shape)
print("test:",test_input.shape)
# Out:
# Train: (5197, 3)
# test: (1300, 3)

# %% [markdown]
# ### 로지스틱 회귀이므로 표준화하기

# %%
from sklearn.preprocessing import StandardScaler

# %%
ss = StandardScaler()
ss.fit(train_input)
train_scaled= ss.transform(train_input)
test_scaled= ss.transform(test_input)

# %% [markdown]
# #### 로지스틱 회귀 모델

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()
lr.fit(train_scaled, train_target)
print("train:",lr.score(train_scaled,train_target))
print("test:",lr.score(test_scaled,test_target))
# Out:
# train: 0.7808350971714451
# test: 0.7776923076923077

# %% [markdown]
# # 가중치와 편차 구하기

# %%
print(lr.coef_,lr.intercept_)
# Out:
# [[ 0.51268071  1.67335441 -0.68775646]] [1.81773456]

# %% [markdown]
# #### 결정트리

# %% [markdown]
# : 선형회귀나 kNN처럼 전처리 과정이 필요 없다.

# %% [markdown]
# #### Decision Tree를 이용한 모델의 생성

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt = DecisionTreeClassifier(random_state=42)
dt.fit(train_input,train_target)
print("train:",dt.score(train_input,train_target))
print("test:",dt.score(test_input,test_target))
# Out:
# train: 0.996921300750433
# test: 0.8584615384615385

# %%
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree

# %%
plt.figure(figsize=(10,7))
plot_tree(dt)
plt.show()

# %%
plt.figure(figsize=(10,7))
plot_tree(
    dt,
    max_depth=1,
    filled=True
)
    
plt.show()

# %%
dt = DecisionTreeClassifier(
    max_depth=3
)
dt.fit(train_input,train_target)

print("train:",dt.score(train_input,train_target))
print("test:",dt.score(test_input,test_target))
# Out:
# train: 0.8454877814123533
# test: 0.8415384615384616

# %%
from sklearn.model_selection import cross_validate
scores=cross_validate(dt)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[64], line 2
#       1 from sklearn.model_selection import cross_validate
# ----> 2 scores=cross_validate(dt)
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py:196, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     193 func_sig = signature(func)
#     195 # Map *args/**kwargs to the function signature
# --> 196 params = func_sig.bind(*args, **kwargs)
#     197 params.apply_defaults()
#     199 # ignore self/cls and positional/keyword markers
#
# File ~\anaconda3\Lib\inspect.py:3304, in Signature.bind(self, *args, **kwargs)
#    3299 def bind(self, /, *args, **kwargs):
#    3300     """Get a BoundArguments object, that maps the passed `args`
#    3301     and `kwargs` to the function's signature.  Raises `TypeError`
#    3302     if the passed arguments can not be bound.
#    3303     """
# -> 3304     return self._bind(args, kwargs)
#
# File ~\anaconda3\Lib\inspect.py:3217, in Signature._bind(self, args, kwargs, partial)
#    3215                 msg = 'missing a required{argtype} argument: {arg!r}'
#    3216                 msg = msg.format(arg=param.name, argtype=argtype)
# -> 3217                 raise TypeError(msg) from None
#    3218 else:
#    3219     # We have a positional argument to process
#    3220     try:
#
# TypeError: missing a required argument: 'X'

# %%
# !pip install optuna
# Out:
# Collecting optuna
#   Downloading optuna-4.9.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: alembic>=1.5.0 in c:\users\user\anaconda3\lib\site-packages (from optuna) (1.18.4)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.10.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numpy in c:\users\user\anaconda3\lib\site-packages (from optuna) (2.3.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\anaconda3\lib\site-packages (from optuna) (25.0)
# Requirement already satisfied: sqlalchemy>=1.4.2 in c:\users\user\anaconda3\lib\site-packages (from optuna) (2.0.43)
# Requirement already satisfied: tqdm in c:\users\user\anaconda3\lib\site-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in c:\users\user\anaconda3\lib\site-packages (from optuna) (6.0.3)
# Requirement already satisfied: Mako in c:\users\user\anaconda3\lib\site-packages (from alembic>=1.5.0->optuna) (1.3.11)
# Requirement already satisfied: typing-extensions>=4.12 in c:\users\user\anaconda3\lib\site-packages (from alembic>=1.5.0->optuna) (4.15.0)
# Requirement already satisfied: greenlet>=1 in c:\users\user\anaconda3\lib\site-packages (from sqlalchemy>=1.4.2->optuna) (3.2.4)
# Requirement already satisfied: colorama in c:\users\user\anaconda3\lib\site-packages (from colorlog->optuna) (0.4.6)
# Requirement already satisfied: MarkupSafe>=0.9.2 in c:\users\user\anaconda3\lib\site-packages (from Mako->alembic>=1.5.0->optuna) (3.0.2)
# Downloading optuna-4.9.0-py3-none-any.whl (425 kB)
# Downloading colorlog-6.10.1-py3-none-any.whl (11 kB)
# Installing collected packages: colorlog, optuna
#
#    -------------------- ------------------- 1/2 [optuna]
#    -------------------- ------------------- 1/2 [optuna]
#    -------------------- ------------------- 1/2 [optuna]
#    -------------------- ------------------- 1/2 [optuna]
#    ---------------------------------------- 2/2 [optuna]
#
# Successfully installed colorlog-6.10.1 optuna-4.9.0
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Cache entry deserialization failed, entry ignored

# %%
from sklearn.ensemble import
