# %%
import pandas as pd
iris=pd.read_csv("../Data/iris.csv")
iris.head()
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth         Name
# 0          5.1         3.5          1.4         0.2  Iris-setosa
# 1          4.9         3.0          1.4         0.2  Iris-setosa
# 2          4.7         3.2          1.3         0.2  Iris-setosa
# 3          4.6         3.1          1.5         0.2  Iris-setosa
# 4          5.0         3.6          1.4         0.2  Iris-setosa

# %%
iris_data=iris[['SepalLength','SepalWidth',
               'PetalLength','PetalWidth']]
iris_target=iris['Name']

# %%
print(iris_target.shape)
print(iris_data.shape)
# Out:
# (150,)
# (150, 4)

# %%
from sklearn.model_selection import train_test_split

# %%
train_data, test_data, train_target, test_target = train_test_split(
    iris_data,
    iris_target,
    test_size=0.2,
    random_state=42,
    stratify=iris_target
)

# %%
print(train_data.shape)
print(test_data.shape)
print(train_target.shape)
print(test_target.shape)
# Out:
# (120, 4)
# (30, 4)
# (120,)
# (30,)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
clf = RandomForestClassifier()
clf.fit(train_data,train_target)
# Out:
# RandomForestClassifier()

# %%
knr.fit(train_input,train_target)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 knr.fit(train_input,train_target)
#
# NameError: name 'knr' is not defined

# %%
#### 길이가 50cm인 생선의 무게 예측

# %%
knr.predict([{50}])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 knr.predict([{50}])
#
# NameError: name 'knr' is not defined

# %%
# 시각화로 확인

# %%
from sklearn.linear_model import LinearRegression

# %%
lr.predict([[50]])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 lr.predict([[50]])
#
# NameError: name 'lr' is not defined

# %%
# Out:
#   Cell In[28], line 1
#     39.01714496tq
#               ^
# SyntaxError: invalid decimal literal

# %%
###산점도 그려보기

# %%
plt.figure(figsize=(10,5))
plt.scatter(train_input,train_target)
plt.plot([15,50],
         [15*lr.coef_+lr.intercept_,50*lr.coef_+lr.intercept_])

plt.show
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 plt.figure(figsize=(10,5))
#       2 plt.scatter(train_input,train_target)
#       3 plt.plot([15,50],
#       4          [15*lr.coef_+lr.intercept_,50*lr.coef_+lr.intercept_])
#
# NameError: name 'plt' is not defined

# %%
### 특성 공학
#### 다항 회귀
#### 다중회귀
