# %%
a=1

# %% [markdown]
# ### 특성(Feature) 공학과 규제(Regularization : 정형화)

# %%
import pandas as pd

# %%
df=pd.read_csv("../Data/fish.csv")
df.head()
# Out:
#    length   height   width
# 0     8.4     2.11    1.41
# 1    13.7     3.53    2.00
# 2    15.0     3.82    2.43
# 3    16.2     4.59    2.63
# 4    17.4     4.59    2.94

# %%
fish_full=df.to_numpy()
fish_full[:5]
# Out:
# array([[ 8.4 ,  2.11,  1.41],
#        [13.7 ,  3.53,  2.  ],
#        [15.  ,  3.82,  2.43],
#        [16.2 ,  4.59,  2.63],
#        [17.4 ,  4.59,  2.94]])

# %%
df=pd.read_csv("../Data/fish_weight.csv")
df.head()
# Out:
#    weight
# 0     5.9
# 1    32.0
# 2    40.0
# 3    51.5
# 4    70.0

# %%
fish_weight=df.to_numpy()
fish_weight[:5]
# Out:
# array([[ 5.9],
#        [32. ],
#        [40. ],
#        [51.5],
#        [70. ]])

# %%
from sklearn.model_selection import train_test_split

# %%
train_input,test_input,train_target,test_target= \
    train_test_split(
        fish_full,
        fish_weight,
        random_state=42
    )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 2
#       1 train_input,test_input,train_target,test_target= \
# ----> 2     train_test_split()
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
#     220     # When the function is just a wrapper around an estimator, we allow
#     221     # the function to delegate validation to the estimator, but we replace
#     222     # the name of the estimator by the name of the function in the error
#     223     # message to avoid confusion.
#     224     msg = re.sub(
#     225         r"parameter of \w+ must be",
#     226         f"parameter of {func.__qualname__} must be",
#     227         str(e),
#     228     )
#
# File ~\anaconda3\Lib\site-packages\sklearn\model_selection\_split.py:2914, in train_test_split(test_size, train_size, random_state, shuffle, stratify, *arrays)
#    2912 n_arrays = len(arrays)
#    2913 if n_arrays == 0:
# -> 2914     raise ValueError("At least one array required as input")
#    2916 arrays = indexable(*arrays)
#    2918 n_samples = _num_samples(arrays[0])
#
# ValueError: At least one array required as input

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
poly = PolynomialFeatures()
poly.fit([[2,3]])
poly.transform([[2,3]])
# Out:
# array([[1., 2., 3., 4., 6., 9.]])

# %%
df=pd.read_csv("../Data/fishes.csv")
df.head()
# Out:
#   Species  Weight  Length  Diagonal   Height   Width
# 0   Bream   242.0    25.4      30.0  11.5200  4.0200
# 1   Bream   290.0    26.3      31.2  12.4800  4.3056
# 2   Bream   340.0    26.5      31.1  12.3778  4.6961
# 3   Bream   363.0    29.0      33.5  12.7300  4.4555
# 4   Bream   430.0    29.0      34.0  12.4440  5.1340

# %%
fishes=df.to_numpy()
fishes[:5]
# Out:
# array([['Bream', 242.0, 25.4, 30.0, 11.52, 4.02],
#        ['Bream', 290.0, 26.3, 31.2, 12.48, 4.3056],
#        ['Bream', 340.0, 26.5, 31.1, 12.3778, 4.6961],
#        ['Bream', 363.0, 29.0, 33.5, 12.73, 4.4555],
#        ['Bream', 430.0, 29.0, 34.0, 12.444, 5.134]], dtype=object)

# %%
train_input,test_input,train_target,test_target= \
    train_test_split(
        fishes_full,
        fishes_weight,
        random_state=42
    )
