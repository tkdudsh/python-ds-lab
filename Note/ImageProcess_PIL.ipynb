# %%
from PIL import Image

# %%
cat = Image.open("../Data/cat.png")
cat
import math
size = math.trunc(cat.width/8),math.trunc(cat.height/8)
catThumb=cat.copy()
catThumb.thumbnail(size)
catThumb.save("../Data/cat_thumb.png")
catThumb
# Out:
# <PIL.Image.Image image mode=RGB size=156x156>

# %%
# Image Layer 확인

cat.getbands()
# Out:
# ('R', 'G', 'B')

# %% [markdown]
# #### Modes
#
# - L : black and white
# - RGB : True Color
# - RGBA: 투명도 있는 True Color
# - YCbCr : Video

# %%
cat.size
# Out:
# (1254, 1254)

# %%
cat.format
# Out:
# 'PNG'

# %%
# Convert to JPEG
cat.save("../Data/cat1.jpg")

# %%
record = Image.open("../Data/record.png")
record
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=512x512>

# %%
record.size
# Out:
# (512, 512)

# %%
import math
size = math.trunc(record.width/10),math.trunc(record.height/10)
recordThumb=record.copy()
recordThumb.thumbnail(size)
recordThumb.save("../Data/record_thumb.png")
recordThumb
# Out:
# <PIL.Image.Image image mode=RGBA size=51x51>

# %%
position=(50,50)
catMerge=catThumb.copy()
catMerge.paste(recordThumb,position)
catMerge
# Out:
# <PIL.Image.Image image mode=RGB size=156x156>

# %%
#### image Flip

# %%
catFlip=catThumb.copy()
catFlip.transpose(Image.Transpose.FLIP_LEFT_RIGHT)
# Out:
# <PIL.Image.Image image mode=RGB size=156x156>

# %%
catFlip=catThumb.copy()
catFlip.transpose(Image.Transpose.FLIP_TOP_BOTTOM)
# Out:
# <PIL.Image.Image image mode=RGB size=156x156>

# %%
import numpy as np

# %%
catThumb.convert("L")
# Out:
# <PIL.Image.Image image mode=L size=156x156>
