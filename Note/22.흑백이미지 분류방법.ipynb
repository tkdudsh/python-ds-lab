# %% [markdown]
# ### 평균과 가까운 사진 고르기

# %%
import numpy as np

# %%
import numpy as np
import os

# Data 폴더 만들기
os.makedirs("../Data", exist_ok=True)

# 300장짜리 100x100 이미지 데이터 생성
fruits = np.random.randint(0, 256, size=(300, 100, 100), dtype=np.uint8)

# npy 파일로 저장
np.save("../Data/fruits.npy", fruits)

# %%
fruits=np.load("../Data/fruits.npy")
fruits.shape
# Out:
# (300, 100, 100)

# %%
# 3차원 데이터를 2차원 데이터로 변경
fruits_2d = fruits.reshape(-1,100*100)
fruits_2d.shape
# Out:
# (300, 10000)

# %%
from sklearn.cluster import KMeans

# %%
km = KMeans(
    n_clusters=3
)
km.fit(fruits_2d)
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# KMeans(n_clusters=3)

# %%
def draw_fruits(arr, ratio=1):
    n = len(arr) 
    rows = int(np.ceil(n/10))

# %%
draw_fruits(fruits[km.labels_ == 0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 draw_fruits(fruits[km.labels_ == 0])
#
# NameError: name 'draw_fruits' is not defined

# %%
inertia = []
for k in range(2,7):
    km = KMeans(
        n_clusters = k
    )
    km.fit(fruits_2d)
    inertia.append(km:inertia_)

plt.plot(
    range(2,7),
inertia)

plt.show()
# Out:
#   Cell In[21], line 7
#     inertia.append(km:inertia_)
#                      ^
# SyntaxError: invalid syntax
