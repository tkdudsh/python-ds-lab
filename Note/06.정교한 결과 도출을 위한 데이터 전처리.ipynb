# %% [markdown]
# ### 정교한 결과 도출을 위한 데이터 전처리

# %%
import pandas as pd

# %%
fruits = pd.read_csv('../Data/fruits.csv')
fruits.head()
# Out:
#    length  weight   name
# 0    25.4   242.0  apple
# 1    26.3   290.0  apple
# 2    26.5   340.0  apple
# 3    29.0   363.0  apple
# 4    29.0   430.0  apple

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
kn = KNeighborsClassifier() #모델 만들기

kn.fit(train_input,train_target) # 학습 시키기

print(kn.score(train_input,train_target))#검증하기
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 3
#       1 kn = KNeighborsClassifier() #모델 만들기
# ----> 3 kn.fit(train_input,train_target) # 학습 시키기
#       5 print(kn.score(train_input,train_target))#검증하기
#
# NameError: name 'train_input' is not defined

# %%
# length가 25cm이고 weight가 150g인 과일은?

kn.predict([25,150])
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# Cell In[12], line 3
#       1 # length가 25cm이고 weight가 150g인 과일은?
# ----> 3 kn.predict([25,150])
#
# File ~\anaconda3\Lib\site-packages\sklearn\neighbors\_classification.py:257, in KNeighborsClassifier.predict(self, X)
#     241 def predict(self, X):
#     242     """Predict the class labels for the provided data.
#     243
#     244     Parameters
#    (...)    255         Class labels for each data sample.
#     256     """
# --> 257     check_is_fitted(self, "_fit_method")
#     258     if self.weights == "uniform":
#     259         if self._fit_method == "brute" and ArgKminClassMode.is_usable_for(
#     260             X, self._fit_X, self.metric
#     261         ):
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1754, in check_is_fitted(estimator, attributes, msg, all_or_any)
#    1751     return
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(
    25,
    150,
    marker="^",
    c="red"
)
plt.xlabel('Length')
plt.ylabel('Weight')

plt.show()

# %%
#표준점수 = (feature-평균)/표준편차

# %%
train_scaled=scaler.transform(train_input)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 train_scaled=scaler.transform(train_input)
#
# NameError: name 'scaler' is not defined

# %%
# feature 와 target 분
